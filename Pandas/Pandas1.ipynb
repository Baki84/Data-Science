# %%
import numpy as np
import pandas as pd

# %%
# !python -c "import pandas; print(pandas.__version__)"
# Out:
# 3.0.3

# %%
#String
country =['India','pakistan','USA','Nepal','Srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: str

# %%
#integers

runs=[13,24,56,78,1000]
pd.Series(runs)
# Out:
# 0      13
# 1      24
# 2      56
# 3      78
# 4    1000
# dtype: int64

# %%
#custom index

marks = [67,57,89,100]
subjects=['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
#setting a name

marks=pd.Series(marks,index=subjects,name='Shashank ke marks') 
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Shashank ke marks, dtype: int64

# %%
#series from dict

marks ={
    'maths':67,
    'english':57,
    'secience':89,
    'hindi':100
}
marks_series = pd.Series(marks,name='Shashank ke marks')
marks_series
# Out:
# maths        67
# english      57
# secience     89
# hindi       100
# Name: Shashank ke marks, dtype: int64

# %%
#SERIES ATTRIBUTE

# %%
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'Shashank ke marks'

# %%
#is_unique
marks_series.is_unique
# Out:
# True

# %%
#index
marks_series.index
# Out:
# Index(['maths', 'english', 'secience', 'hindi'], dtype='str')

# %%
#values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
#SERIES USING read_csv

# %%
#with one col
subs = pd.read_csv('subs.csv').squeeze()
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk = pd.read_csv('kohli_ipl.csv',index_col = 'match_no').squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies =pd.read_csv('bollywood.csv',index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
#SERIES METHOD 
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
vk.head(20)
# Out:
# match_no
# 1      1
# 2     23
# 3     13
# 4     12
# 5      1
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# 17    22
# 18    19
# 19    16
# 20    15
# Name: runs, dtype: int64

# %%
vk.tail(8)
# Out:
# match_no
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#SAMPLE
movies.sample()
# Out:
# movie
# Bhaiaji Superhit    Sunny Deol
# Name: lead, dtype: str

# %%
movies.sample(5)
# Out:
# movie
# Cigarette Ki Tarah                Ashok Banthia
# Waisa Bhi Hota Hai Part II         Arshad Warsi
# Fanaa (2006 film)                    Aamir Khan
# Waarrior Savitri               Niharica Raizada
# MSG: The Warrior Lion Heart         Ashok Insan
# Name: lead, dtype: str

# %%
#value_counts -> movies

movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
#sort_values -> inplace

vk.sort_values(ascending=False).head(5).values
# Out:
# array([113, 109, 108, 100, 100])

# %%
#Series Maths Methods

# %%
#COUNT - it dont count missing values but SIZE count missing values(example - nan )

vk.count()
# Out:
# np.int64(215)

# %%
#sum -> product

subs.sum()
# Out:
# np.int64(49510)

# %%
#mean,median,modde,std,var

# subs.mean()
# vk.median()
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str
# 62.6750230372527
# 688.0024777222343

# %%
#min/max

subs.min()
# Out:
# np.int64(33)

# %%
subs.max()
# Out:
# np.int64(396)

# %%
#describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
#series INDEXING

# %%
#integer indexing -> it is not working on negative indexing [-1] like this
x =pd.Series([12,13,14,35,46,57,58,79,9])
x[1]
# Out:
# np.int64(13)

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
movies.iloc[1]
# Out:
# 'Vicky Ahuja'

# %%
#SILICING

# %%
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#fancy Indexing
vk[[1,3,5,6]]
# Out:
# match_no
# 1     1
# 3    13
# 5     1
# 6     9
# Name: runs, dtype: int64

# %%
#indexing with Lables -> fancy indexing
movies['Why Cheat India']
# Out:
# 'Emraan Hashmi'

# %%
#Editing Series

# %%
#using indexing
marks_series.loc['english'] =69

# %%
marks_series
# Out:
# maths        67
# english      69
# secience     89
# hindi       100
# Name: Shashank ke marks, dtype: int64

# %%
#what if an index doesnot exists

marks_series['sst'] =90
marks_series
# Out:
# maths        67
# english      69
# secience     89
# hindi       100
# sst          90
# Name: Shashank ke marks, dtype: int64

# %%
#silicing
runs
# Out:
# [13, 24, 56, 78, 1000]

# %%
runs[2:4]=[100,100]

# %%
runs
# Out:
# [13, 24, 100, 100, 1000]

# %%
#fancy indexing
runs = pd.Series(runs)

runs[[0,2,4]] =[0,0,0]
runs
# Out:
# 0      0
# 1     24
# 2      0
# 3    100
# 4      0
# dtype: int64

# %%
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
#series with python Functionalities

# %%
#len/type/dir/sortred/max/min

# %%
print(len(subs))
print(type(subs))
# print(dir(subs))
print(max(subs))
print(min(subs))
print(sorted(subs))
# Out:
# 365
# <class 'pandas.Series'>
# 396
# 33
# ...

# %%
#type Conversion
dict(marks_series)
# Out:
# {'maths': np.int64(67),
#  'english': np.int64(69),
#  'secience': np.int64(89),
#  'hindi': np.int64(100),
#  'sst': np.int64(90)}

# %%
#membership operator

'2 States (2014 film)' in movies
# Out:
# True

# %%
#looping
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
#find no of 50's and 100's scored by kohli

vk[vk >= 50].size
# Out:
# 50

# %%
#find no of ducks

vk[vk ==0].size
# Out:
# 9

# %%
#count the no of days when i had more than 200 subs a day

subs[subs > 200].size
# Out:
# 59

# %%
#find actors who have done more than 20 movies

nums=movies.value_counts()
nums[nums > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
#plotting a graph on series

subs.plot()
# Out:
# <Axes: >

# %%
subs.plot(title="Subscriber Growth Over Time", color="g")
# Out:
# <Axes: title={'center': 'Subscriber Growth Over Time'}>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar',color="r")
# Out:
# <Axes: xlabel='lead'>
