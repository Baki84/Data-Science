# %%
import numpy as np;
import pandas as pd;

# %%
#value_counts(series and dataframes)

marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14],
    [80,70,14]
],columns=['iq','marks','package'])
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14
# 4   80     70       14

# %%
marks.value_counts()
# Out:
# iq   marks  package
# 80   70     14         2
# 100  80     10         1
# 90   70     7          1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl=pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#Find which player has won most potm -> in finals ad qualifiers
# ipl.head(1)
# Player_of_Match 
# MatchNumber

ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# KA Pollard           3
# SK Raina             3
# JJ Bumrah            2
# SR Watson            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# YK Pathan            2
# A Kumble             2
# HH Pandya            1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# KV Sharma            1
# NM Coulter-Nile      1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# RG Sharma            1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# Harbhajan Singh      1
# BJ Hodge             1
# MEK Hussey           1
# MS Bisla             1
# ...

# %%
#Toss decision plot

ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
#how may each team has played

ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).plot(kind='pie')
# Out:
# <Axes: >

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#sort_values(Series & dataFrame) -> ascending ->na_position -> inplace - multiplle_cols
movies.sort_values('title_x',ascending=False).head(2)
# Out:
#                     title_x    imdb_id  \
# 1623               Zubeidaa  tt0255713
# 939   Zor Lagaa Ke...Haiya!  tt1479857
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
# 939   https://en.wikipedia.org/wiki/Zor_Lagaa_Ke...H...
#
#                      title_y          original_title  is_adult  \
# 1623                Zubeidaa                Zubeidaa         0
# 939   Zor Lagaa Ke... Haiya!  Zor Lagaa Ke... Haiya!         0
#
#       year_of_release runtime                   genres  imdb_rating  \
# 1623             2001     153  Biography|Drama|History          6.2
# 939              2009      \N      Comedy|Drama|Family          6.4
#
#       imdb_votes                                              story  \
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]
    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name')
# Out:
#          name college branch   cgpa  package
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN

# %%
students.sort_values('name',na_position='first',inplace=True)

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series)
batsman=pd.read_csv('batsman_runs_ipl.csv').head()
batsman.sample(2)
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161

# %%
batsman['batsman_rank']= batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('batsman_rank')
# Out:
#            batter  batsman_run  batsman_rank
# 0  A Ashish Reddy          280           1.0
# 1        A Badoni          161           2.0
# 3        A Chopra           53           3.0
# 4     A Choudhary           25           4.0
# 2      A Chandila            4           5.0

# %%
#sort_index(seies and dataframs)

# %%
marks ={
    'maths': 67,
    'english':57,
    'science':89,
    'hindi':100
}
marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index()
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#SET_INDEX(DATAFRAM) -> inplace
batsman.set_index('batter')
# Out:
#                 batsman_run  batsman_rank
# batter
# A Ashish Reddy          280           1.0
# A Badoni                161           2.0
# A Chandila                4           5.0
# A Chopra                 53           3.0
# A Choudhary              25           4.0

# %%
#reset_index (seriess, dataframe) -> drop parameter
batsman.reset_index()
# Out:
#    index          batter  batsman_run  batsman_rank
# 0      0  A Ashish Reddy          280           1.0
# 1      1        A Badoni          161           2.0
# 2      2      A Chandila            4           5.0
# 3      3        A Chopra           53           3.0
# 4      4     A Choudhary           25           4.0

# %%
#how to replace existing index withoput loosing

batsman.reset_index().set_index('batsman_rank')
# Out:
#               index          batter  batsman_run
# batsman_rank
# 1.0               0  A Ashish Reddy          280
# 2.0               1        A Badoni          161
# 5.0               2      A Chandila            4
# 3.0               3        A Chopra           53
# 4.0               4     A Choudhary           25

# %%
#unique(series)
temo= pd.Series([1,2,2,2,3,4,56,65,5,5,np.nan,np.nan,np.nan])
temo.unique()
# Out:
# array([ 1.,  2.,  3.,  4., 56., 65.,  5., nan])

# %%
ipl['Season'].unique()
# Out:
# <ArrowStringArray>
# [   '2022',    '2021', '2020/21',    '2019',    '2018',    '2017',    '2016',
#     '2015',    '2014',    '2013',    '2012',    '2011', '2009/10',    '2009',
#  '2007/08']
# Length: 15, dtype: str

# %%
(ipl['Season'].nunique())
# Out:
# 15

# %%
#isnull(series , dataframe)
students['name'].isnull()
# Out:
# 3     True
# 5     True
# 7     True
# 9     True
# 8    False
# 1    False
# 4    False
# 0    False
# 6    False
# 2    False
# Name: name, dtype: bool

# %%
#notnull(series , dataframe)
students['name'].notnull()
# Out:
# 3    False
# 5    False
# 7    False
# 9    False
# 8     True
# 1     True
# 4     True
# 0     True
# 6     True
# 2     True
# Name: name, dtype: bool

# %%
#hasnans(series)
students['name'].hasnans
# Out:
# True

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 3   True     True    True   True     True
# 5   True    False   False  False    False
# 7   True     True   False  False    False
# 9   True    False    True   True     True
# 8  False     True   False  False     True
# 1  False    False   False  False    False
# 4  False     True   False  False    False
# 0  False    False   False  False    False
# 6  False    False   False  False    False
# 2  False    False   False  False    False

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 3  False    False   False  False    False
# 5  False     True    True   True     True
# 7  False    False    True   True     True
# 9  False     True   False  False    False
# 8   True    False    True   True    False
# 1   True     True    True   True     True
# 4   True    False    True   True     True
# 0   True     True    True   True     True
# 6   True     True    True   True     True
# 2   True     True    True   True     True

# %%
#dropna(series+dataframe0
students.dropna()
# Out:
#       name college branch  cgpa  package
# 1    ankit     iit     it  8.25      5.0
# 0   nitish     bit    eee  6.66      4.0
# 6  rishabh    ssit    civ  7.40      8.0
# 2   rupesh     vit    cse  6.41      6.0

# %%
students['name'].dropna()
# Out:
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: str

# %%
#fillna(series+dataframe0
students.fillna(0)
# Out:
#          name college branch   cgpa  package
# 3           0       0      0   0.00      0.0
# 5           0    vlsi     ce   9.00      7.0
# 7           0       0    cse  10.00      9.0
# 9           0     git      0   0.00      0.0
# 8      aditya       0    bio   7.40      0.0
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay       0     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students['name'].fillna(9)
# Out:
# 3             9
# 5             9
# 7             9
# 9             9
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
students['name'].fillna(9)
# Out:
# 3             9
# 5             9
# 7             9
# 9             9
# 8        aditya
# 1         ankit
# 4    mrityunjay
# 0        nitish
# 6       rishabh
# 2        rupesh
# Name: name, dtype: object

# %%
#drop duplicates(series,dataframe)
marks.duplicated().sum()
# Out:
# np.int64(1)

# %%
marks.drop_duplicates()
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14

# %%
#find the last match played by virat kohli in delhi
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
def did_kohli_plays(players_list):
    return 'V Kohli' in players_list

# %%
ipl['did_kohli_plays'] = ipl['all_players'].apply(did_kohli_play)

# Use the same column name (with 's')
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_plays'] == True)].drop_duplicates(subset=['City','did_kohli_plays'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... Margin method Player_of_Match  \
# 208          bat  ...   16.0    NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                            all_players did_kohli_plays
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...            True
#
# ...

# %%
#drop(series,dataframe)
t =pd.Series([1,2,3,4])
t.drop(index=[0,1])
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
students.drop(columns=['branch','cgpa'])
# Out:
#          name college  package
# 3         NaN     NaN      NaN
# 5         NaN    vlsi      7.0
# 7         NaN     NaN      9.0
# 9         NaN     git      NaN
# 8      aditya     NaN      NaN
# 1       ankit     iit      5.0
# 4  mrityunjay     NaN      6.0
# 0      nitish     bit      4.0
# 6     rishabh    ssit      8.0
# 2      rupesh     vit      6.0

# %%
students.drop(index=[0,1])
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
#apply(dataframe,series)

temp = pd.Series([10,20,30,40,50])
temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
def sigmoid(value):
    return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
points_df = pd.DataFrame(
    {
        '1st point': [(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)
points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def eucliden(row):
    pt_A = row['1st point']
    pt_B = row['2nd point']
    return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance'] = points_df.apply(eucliden, axis=1)
print(points_df)
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
